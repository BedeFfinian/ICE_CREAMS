# %% [markdown]
# # Training Intertidal Classification of Europe: Categorising Reflectance of Emerged Areas of Marine vegetation using Sentinel 2

# %% [markdown]
# # ICE CREAMS

# %% [markdown]
# Import fastbook module and required elements within it to run a tabular learner.

# %%
from fastai.tabular.all import *
import glob
import pandas as pd

# %% [markdown]
# Read in training data in wide format.
# Each version of the model is stored in a separate folder inside Data/Input/Training of the repository. csv files have also been separated into 100,000 row files to minimise file sizes. Therefore, we need to combine them all to create the full training dataframe.
#
# Training data for ICE CREAMS has 26 features and one label/y column with 9 classes. Features are 12 Bottom of Atmosphere reflectance columns, 12 Min-Max standardised reflectance columns, and 2 columns for Normalised Difference Vegetation Index (NDVI) and Normalised Difference Water Index (NDWI).

# %%
Training_Location_V1_1=glob.glob("Data/Input/Training/V1_1/*.csv")
#Training_Location_V1_2=glob.glob("Data/Input/Training/V1_2/*.csv")
#Training_Location_V1_3=glob.glob("Data/Input/Training/V1_3/*.csv")

# %%
Training_df_V1_1 = pd.concat((pd.read_csv(f) for f in Training_Location_V1_1), ignore_index=True)
#Training_df_V1_2 = pd.concat((pd.read_csv(f) for f in Training_Location_V1_2), ignore_index=True)
#Training_df_V1_3 = pd.concat((pd.read_csv(f) for f in Training_Location_V1_3), ignore_index=True)

# %%
#df_nn = pd.concat([Training_df_V1_1,Training_df_V1_2,Training_df_V1_3])
df_nn=Training_df_V1_1

# %%
df_nn
# Out:
#                True_Class  Reflectance_B02  Reflectance_B03  Reflectance_B04  \
# 0       Microphytobenthos              824             1074              944
# 1       Microphytobenthos              852             1122              944
# 2       Microphytobenthos              891             1142              986
# 3       Microphytobenthos              869             1222             1012
# 4       Microphytobenthos              754             1064              844
# ...                   ...              ...              ...              ...
# 371120      Bare Sediment              758             1050             1104
# 371121      Bare Sediment              779             1052             1112
# 371122      Bare Sediment              747             1028             1112
# 371123      Bare Sediment              756              992             1092
# 371124      Bare Sediment              719             1024             1096
#
#         Reflectance_B08  Reflectance_B05  Reflectance_B06  Reflectance_B07  \
# 0                  1910             1535             1746             1759
# 1                  1958             1535             1746             1759
# 2                  1676             1614             1775             1803
# 3                  1910             1614             1775             1803
# 4                  2120             1625             1893             2011
# ...                 ...              ...              ...              ...
# 371120             1398             1326             1278             1375
# 371121             1362             1326             1278             1375
# 371122             1342             1318             1273             1349
# 371123             1300             1318             1273             1349
# 371124             1324             1293             1273             1334
#
#         Reflectance_B11  Reflectance_B12  ...  Reflectance_Stan_B05  \
# 0                  1204              661  ...              0.699760
# 1                  1204              661  ...              0.673863
# 2                  1174              652  ...              0.832180
# 3                  1174              652  ...              0.764706
# 4                  1301              710  ...              0.648936
# ...                 ...              ...  ...                   ...
# 371120              291              108  ...              0.944186
# 371121              291              108  ...              0.961326
# 371122              214               87  ...              0.975436
# 371123              214               87  ...              0.975436
# 371124              186               62  ...              0.967767
#
#         Reflectance_Stan_B06  Reflectance_Stan_B07  Reflectance_Stan_B11  \
# 0                   0.868695              0.879103              0.434748
# 1                   0.836546              0.846569              0.418658
# 2                   0.971453              0.995675              0.451557
# 3                   0.892687              0.914944              0.414944
# 4                   0.839007              0.922695              0.419149
# ...                      ...                   ...                   ...
# 371120              0.906977              0.982171              0.141860
# 371121              0.923441              1.000000              0.144436
# 371122              0.939778              1.000000              0.100634
# 371123              0.939778              1.000000              0.100634
# 371124              0.952044              1.000000              0.097484
#
#         Reflectance_Stan_B12  Reflectance_Stan_B8A  Reflectance_Stan_B01  \
# 0                        0.0              0.919936              0.045637
# 1                        0.0              0.885891              0.043948
# 2                        0.0              0.987024              0.057093
# 3                        0.0              0.906995              0.052464
# 4                        0.0              0.898582              0.023404
# ...                      ...                   ...                   ...
# 371120                   0.0              0.972093              0.325581
# 371121                   0.0              0.989740              0.331492
# 371122                   0.0              0.977813              0.332805
# 371123                   0.0              0.977813              0.332805
# 371124                   0.0              0.977987              0.349843
#
#         Reflectance_Stan_B09      NDVI      NDWI
# 0                   0.918335  0.338472 -0.280161
# 1                   0.884348  0.349414 -0.271429
# 2                   1.000000  0.259204 -0.189496
# 3                   0.918919  0.307324 -0.219668
# 4                   0.880851  0.430499 -0.331658
# ...                      ...       ...       ...
# 371120              0.741085  0.117506 -0.142157
# 371121              0.754538  0.101051 -0.128418
# 371122              0.697306  0.093725 -0.132489
# 371123              0.697306  0.086957 -0.134380
# 371124              0.711478  0.094215 -0.127768
#
# [371125 rows x 27 columns]

# %% [markdown]
# Our labelled column is called True_Class.

# %%
dep_var = "True_Class"
splits = RandomSplitter(valid_pct=0.2)(range_of(df_nn))

# %% [markdown]
# Select which columns are categoric and which are continuous, ICE CREAMS uses just continuous features.

# %%
cont_nn,cat_nn = cont_cat_split(df_nn, dep_var=dep_var)

# %% [markdown]
# Minimal pre processing is carried out but if any missing data is present it should be filled.

# %%
procs_nn = [FillMissing]
to_nn = TabularPandas(df_nn, procs_nn, cat_nn, cont_nn,
                      splits=splits, 
                      y_names=dep_var, y_block=CategoryBlock())

# %%
dls = to_nn.dataloaders()

# %%
y = to_nn.train.y

# %% [markdown]
# Cleate the learner, which is a tabular learner with 9 output classes.

# %%
learn = tabular_learner(dls,n_out=9)

# %% [markdown]
# Fine tune the learner/model over 20 epochs. Default fine tuning is carried out with ADAM optimiser.

# %%
learn.fine_tune(20)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='46' class='' max='4639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.99% [46/4639 00:00<00:22 1.8664]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 learn.fine_tune(20)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/callback/schedule.py:167, in fine_tune(self, epochs, base_lr, freeze_epochs, lr_mult, pct_start, div, **kwargs)
#     165 "Fine tune with `Learner.freeze` for `freeze_epochs`, then with `Learner.unfreeze` for `epochs`, using discriminative LR."
#     166 self.freeze()
# --> 167 self.fit_one_cycle(freeze_epochs, slice(base_lr), pct_start=0.99, **kwargs)
#     168 base_lr /= 2
#     169 self.unfreeze()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/callback/schedule.py:121, in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt, start_epoch)
#     118 lr_max = np.array([h['lr'] for h in self.opt.hypers])
#     119 scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     120           'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 121 self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=start_epoch)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:272, in Learner.fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     270 self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     271 self.n_epoch = n_epoch
# --> 272 self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:261, in Learner._do_fit(self)
#     259 for epoch in range(self.n_epoch):
#     260     self.epoch=epoch
# --> 261     self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:255, in Learner._do_epoch(self)
#     254 def _do_epoch(self):
# --> 255     self._do_epoch_train()
#     256     self._do_epoch_validate()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:247, in Learner._do_epoch_train(self)
#     245 def _do_epoch_train(self):
#     246     self.dl = self.dls.train
# --> 247     self._with_events(self.all_batches, 'train', CancelTrainException)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:213, in Learner.all_batches(self)
#     211 def all_batches(self):
#     212     self.n_iter = len(self.dl)
# --> 213     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:243, in Learner.one_batch(self, i, b)
#     241 b = self._set_device(b)
#     242 self._split(b)
# --> 243 self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:231, in Learner._do_one_batch(self)
#     229 self('after_loss')
#     230 if not self.training or not len(self.yb): return
# --> 231 self._do_grad_opt()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:219, in Learner._do_grad_opt(self)
#     218 def _do_grad_opt(self):
# --> 219     self._with_events(self._backward, 'backward', CancelBackwardException)
#     220     self._with_events(self._step, 'step', CancelStepException)
#     221     self.opt.zero_grad()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/learner.py:215, in Learner._backward(self)
# --> 215 def _backward(self): self.loss_grad.backward()
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/_tensor.py:617, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     573 r"""Computes the gradient of current tensor wrt graph leaves.
#     574
#     575 The graph is differentiated using the chain rule. If the tensor is
#    (...)    614         used to compute the :attr:`tensors`.
#     615 """
#     616 if has_torch_function_unary(self):
# --> 617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#     620         self,
#     621         gradient=gradient,
#     622         retain_graph=retain_graph,
#     623         create_graph=create_graph,
#     624         inputs=inputs,
#     625     )
#     626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/overrides.py:1742, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1734     warnings.warn(
#    1735         "Defining your `__torch_function__ as a plain method is deprecated and "
#    1736         "will be an error in future, please define it as a classmethod.",
#    1737         DeprecationWarning,
#    1738     )
#    1740 # Use `public_api` instead of `implementation` so __torch_function__
#    1741 # implementations can do equality/identity comparisons.
# -> 1742 result = torch_func_method(public_api, types, args, kwargs)
#    1744 if result is not NotImplemented:
#    1745     return result
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/_tensor.py:1648, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1645     return NotImplemented
#    1647 with _C.DisableTorchFunctionSubclass():
# -> 1648     ret = func(*args, **kwargs)
#    1649     if func in get_default_nowrap_functions():
#    1650         return ret
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/ICE_CREAMS/lib/python3.13/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# Export the Pickled Model.

# %%
learn.export('ICECREAMS_V1_1.pkl')
